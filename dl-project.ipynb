# %%
# !git clone https://github.com/luna-droid-0206/DL_Project
# %cd DL_Project
# !ls
# Out:
# fatal: destination path 'DL_Project' already exists and is not an empty directory.
# /kaggle/working/DL_Project
# Brain_Tumor_Segmentation_Report.docx  evaluation  __pycache__	    training
# config.py			      main.py	  README.md
# cs23b1067_kaggle_notebook.ipynb       models	  REPORT.md
# data				      outputs	  requirements.txt

# %%
# !pip install -r requirements.txt

# %%
# !pip install rouge-score nltk transformers scikit-image tqdm

# %%
#!git pull origin main

# %%
# !python main.py
# Out:
# ...
#   Brain Tumor Segmentation — Configuration
# ...
#   Device        : cuda
#   Image size    : 256x256
#   Batch size    : 16
#   Epochs        : 50
#   Learning rate : 0.0001
#   Use text      : True
# ...
#
# [1/7] Building data loaders …
# [BraTSDataset] mode=train | slices=258 | patients~1 | use_text=True
# [BraTSDataset] mode=val | slices=86 | patients~0 | use_text=True
#
# [2/7] Training multimodal model (with text) …
#   Total params     : 43,102,657
#   Trainable params : 43,102,657
#
# ...
#   Training  [with_text]  |  device: cuda
# ...
# Epoch   1/50 | Loss 0.4465/0.8186 | Dice 0.6905/0.3893 | IoU 0.5432/0.2417 | 24.4s
#   ✓ New best val Dice: 0.3893
# Epoch   2/50 | Loss 0.2695/0.8184 | Dice 0.8172/0.4522 | IoU 0.7026/0.2928 | 25.8s
#   ✓ New best val Dice: 0.4522
# Epoch   3/50 | Loss 0.2049/0.8254 | Dice 0.8703/0.3979 | IoU 0.7831/0.2492 | 23.7s
# Epoch   4/50 | Loss 0.1828/0.5143 | Dice 0.8840/0.7085 | IoU 0.8062/0.5567 | 23.2s
#   ✓ New best val Dice: 0.7085
# ...

# %%
#!python main.py --skip_train
